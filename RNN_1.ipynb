# %% [markdown]
# <a href="https://colab.research.google.com/github/shanmugt-hub/ann/blob/main/RNN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
text = "This is GeeksforGeeks a software training institute"
chars = sorted(list(set(text)))
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

# %%
seq_length = 3
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

X = np.array(sequences)
y = np.array(labels)

# %%
print(text[0:3], text[3])
# Out:
# Thi s

# %%
X.shape
# Out:
# (48, 3)

# %%
y.shape
# Out:
# (48,)

# %%
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# %%
X_one_hot.shape
# Out:
# TensorShape([48, 3, 17])

# %%
y_one_hot.shape
# Out:
# TensorShape([48, 17])

# %%
model = Sequential()
model.add(SimpleRNN(50, input_shape=(seq_length, len(chars)), activation='relu'))
model.add(Dense(len(chars), activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 50)             │         3,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 17)             │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,267 (16.67 KB)
#  Trainable params: 4,267 (16.67 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_one_hot, y_one_hot, epochs=100)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0486 - loss: 2.8860
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0764 - loss: 2.8663
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0868 - loss: 2.8441
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1111 - loss: 2.8175
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0799 - loss: 2.8113
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.1111 - loss: 2.7870
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0868 - loss: 2.7749
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.1007 - loss: 2.7609
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.1250 - loss: 2.7343
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1389 - loss: 2.7179
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1910 - loss: 2.7006
# Epoch 12/100
# ...

# %%
start_seq = "This is Geeks for geeks a"
generated_text = start_seq

# %%
for i in range(50):
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))
    prediction = model.predict(x_one_hot)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]
    generated_text += next_char
    print(generated_text)

print("Generated Text:")
print(generated_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# This is Geeks for geeks a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# This is Geeks for geeks a s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# This is Geeks for geeks a so
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# This is Geeks for geeks a sof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# This is Geeks for geeks a soft
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# This is Geeks for geeks a softw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# This is Geeks for geeks a softwa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# This is Geeks for geeks a softwar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# This is Geeks for geeks a software
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# This is Geeks for geeks a software
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# This is Geeks for geeks a software t
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# This is Geeks for geeks a software tr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# This is Geeks for geeks a software tra
# ...

# %%
generated_text[-seq_length:]
# Out:
# 's G'

# %%
np.argmax(15)
# Out:
# np.int64(0)
